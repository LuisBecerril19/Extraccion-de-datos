# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as up
import matplotlib.pyplot as pit
#import seaborn as sns

# %%
#Carga desde un archivo .csv sin indice
data = pd.read_csv("Girona.csv", encoding="latin1")

# %%
#Realizamos una copia del dataframe
data1 = data.copy()

# %%
#Se filtra description con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['description'] = data1['description'].fillna("Casita")

# %%
#Se filtra neighborhood_overview con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['neighborhood_overview'] = data1['neighborhood_overview'].fillna("    ")

# %%
#Se filtra host_location con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['host_location'] = data1['host_location'].fillna("Girona")

# %%
#Se filtra host_about con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['host_about'] = data1['host_about'].fillna("Rentamos casas")

# %%
#Se filtra host_response_time con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['host_response_time'] = data1['host_response_time'].fillna("En menos de una hora")

# %%
#Se filtra host_response_rate con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['host_response_rate'] = data1['host_response_rate'].fillna("100%")

# %%
#Se filtra host_acceptance_rate con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['host_acceptance_rate'] = data1['host_acceptance_rate'].fillna("80%")

# %%
#Se filtra host_is_superhost con el Tercer metodo de sustitucion de valores nulos
#Sustituir valores nulos con un valor numerico en concreto
data1['host_is_superhost'] = data1['host_is_superhost'].fillna(False)
data1
# Out:
#                  id last_scraped           source  \
# 0      1.455100e+04   30/09/2024      city scrape
# 1      4.540000e+04   30/09/2024      city scrape
# 2      7.828200e+04   30/09/2024  previous scrape
# 3      9.334300e+04   30/09/2024  previous scrape
# 4      1.015800e+05   30/09/2024  previous scrape
# ...             ...          ...              ...
# 21438  1.255100e+18   30/09/2024      city scrape
# 21439  1.255130e+18   30/09/2024      city scrape
# 21440  1.255730e+18   30/09/2024      city scrape
# 21441  1.255860e+18   30/09/2024      city scrape
# 21442  1.255860e+18   30/09/2024      city scrape
#
#                                                     name  \
# 0               Cozy & Colorful by Nature (Private Room)
# 1                     Begur - Loft - Costa Brava - SPAIN
# 2                     Bonita casa rodeada de verde campo
# 3      Alquiler de casa en La Costa Brava cerca de playa
# 4      Villa ZEN costa brava ,700m port,beach & resta...
# ...

# %%
#Se filtra neighbourhood con el Cuarto metodo de sustitucion de valores nulos
#Sustituir valores nulos con un string en concreto
data1['neighbourhood'] = data1['neighbourhood'].fillna("80%")

# %%
#Se filtra bathrooms con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['bathrooms']=data1['bathrooms'].fillna(round(data['bathrooms'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra bedrooms con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['bedrooms']=data1['bedrooms'].fillna(round(data['bedrooms'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra beds con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['beds']=data1['beds'].fillna(round(data['beds'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra price con el metodo de la mediana
#Eliminar símbolos no numéricos y convertir a float
data1['price'] = data1['price'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(float)

#Sustituir valores nulos con la mediana
data1['price'] = data1['price'].fillna(round(data1['price'].median(), 1))

# %%
#Se filtra has_availability con el Tercer metodo de sustitucion de valores nulos
#Sustituir valores nulos con un valor numerico en concreto
data1['has_availability'] = data1['has_availability'].fillna(True)
data1
# Out:
#                  id last_scraped           source  \
# 0      1.455100e+04   30/09/2024      city scrape
# 1      4.540000e+04   30/09/2024      city scrape
# 2      7.828200e+04   30/09/2024  previous scrape
# 3      9.334300e+04   30/09/2024  previous scrape
# 4      1.015800e+05   30/09/2024  previous scrape
# ...             ...          ...              ...
# 21438  1.255100e+18   30/09/2024      city scrape
# 21439  1.255130e+18   30/09/2024      city scrape
# 21440  1.255730e+18   30/09/2024      city scrape
# 21441  1.255860e+18   30/09/2024      city scrape
# 21442  1.255860e+18   30/09/2024      city scrape
#
#                                                     name  \
# 0               Cozy & Colorful by Nature (Private Room)
# 1                     Begur - Loft - Costa Brava - SPAIN
# 2                     Bonita casa rodeada de verde campo
# 3      Alquiler de casa en La Costa Brava cerca de playa
# 4      Villa ZEN costa brava ,700m port,beach & resta...
# ...

# %%
#Se filtra review_scores_rating con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_rating']=data1['review_scores_rating'].fillna(round(data['review_scores_rating'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra review_scores_accuracy con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_accuracy']=data1['review_scores_accuracy'].fillna(round(data['review_scores_accuracy'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra review_scores_cleanliness con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_cleanliness']=data1['review_scores_cleanliness'].fillna(round(data['review_scores_cleanliness'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra 'review_scores_checkin' con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_checkin']=data1['review_scores_checkin'].fillna(round(data['review_scores_checkin'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra 'review_scores_communication' con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_communication']=data1['review_scores_communication'].fillna(round(data['review_scores_communication'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra 'review_scores_location' con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_location']=data1['review_scores_location'].fillna(round(data['review_scores_location'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra 'review_scores_value' con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['review_scores_value']=data1['review_scores_value'].fillna(round(data['review_scores_value'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Se filtra 'reviews_per_month' con el Primer metodo de sustitucion de valores nulos
#Sustituir valores nulos con promedio o media
data1['reviews_per_month']=data1['reviews_per_month'].fillna(round(data['reviews_per_month'].mean(),1))
#Round redondea, el ultimo uno toma los decimales

# %%
#Identificar valores nulos por dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                              0
# last_scraped                                    0
# source                                          0
# name                                            0
# description                                     0
# neighborhood_overview                           0
# host_id                                         0
# host_name                                       0
# host_since                                      0
# host_location                                   0
# host_about                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# host_has_profile_pic                            0
# ...
